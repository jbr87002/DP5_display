# %%
from IPython.display import SVG, display, Image
import pickle
import dp5_display
import importlib
from dp5_display import show_results
importlib.reload(dp5_display)
from dp5_display import show_results

# %%
calc_folder_path = '/scratch/jbr46/Litoarbolide_A/O_bridge'

show_results(calc_folder_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 calc_folder_path = '/scratch/jbr46/Litoarbolide_A/O_bridge'
# ----> 3 show_results(calc_folder_path)
#
# File /scratch/jbr46/svg_display/dp5_display.py:17, in show_results(calc_folder_path)
#      14 with open(data_dic_path, 'rb') as f:
#      15     data_dic = pickle.load(f)
# ---> 17 for labels, atom_p, mol_path in zip(data_dic['Clabels'], data_dic['B_ErrorAtomProbs'], data_dic['mols']):
#      18     structure_name = mol_path.split('.')[0]
#      19     full_mol_path = f'{calc_folder_path}/{mol_path}'
#
# KeyError: 'mols'

# %%
import os

imgs_folder_path = os.path.join(calc_folder_path, 'imgs')
svg_contents = []
for filename in os.listdir(imgs_folder_path):
    if filename.endswith('.svg'):
        file_path = os.path.join(imgs_folder_path, filename)
        with open(file_path, 'r') as f:
            svg_content = f.read()
            svg_contents.append(svg_content)


for svg_content in svg_contents:
    display(SVG(svg_content))
